# %% [markdown]
# # Notebook 02 — Text Cleaning & Normalization
#
# **Goal:** transform raw financial news headlines into a clean, consistent text column suitable for NLP modeling.
#
# **Why this step matters:** NLP models are highly sensitive to noise such as inconsistent casing, duplicated headlines, URLs, and formatting artifacts. Cleaning the data once here ensures all downstream analysis is reproducible and comparable.
#
# **Output:** a processed dataset saved to `data/processed/news_clean.parquet` (CSV fallback).

# %% [markdown]
# ## Imports and environment setup
#
# We import standard Python libraries for data manipulation and text processing.
# Display options are adjusted so headline text is fully visible during inspection.

# %%
import re
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 200)

# %% [markdown]
# ## Load raw headline data
#
# We reload the three raw headline datasets from `data/raw/` and reapply
# the same standardization logic used in Notebook 01.
#
# Rebuilding the dataset inside this notebook keeps it self-contained and reproducible.

# %%
DATA_DIR = Path("../data/raw")

cnbc = pd.read_csv(DATA_DIR / "cnbc_headlines.csv")
reuters = pd.read_csv(DATA_DIR / "reuters_headlines.csv")
guardian = pd.read_csv(DATA_DIR / "guardian_headlines.csv")

def standardize(df, source_name):
    df = df.copy()
    df.columns = [c.lower() for c in df.columns]
    df["source"] = source_name
    return df

cnbc = standardize(cnbc, "CNBC")
reuters = standardize(reuters, "Reuters")
guardian = standardize(guardian, "Guardian")

news_df = pd.concat([cnbc, reuters, guardian], ignore_index=True)
news_df.shape
# Out:
# (53650, 4)

# %% [markdown]
# ## Confirm expected columns
#
# Before cleaning, we confirm that the expected text column (`headlines`) exists
# and that the combined dataset contains the necessary metadata fields
# (time and source).

# %%
news_df.columns.tolist()
# Out:
# ['headlines', 'time', 'description', 'source']

# %% [markdown]
# ## Data quality checks: missing values and duplicates
#
# We assess data quality by checking:
# - missing headline text (cannot be used for NLP)
# - duplicate headlines (common across news sources or scrapes)
#
# These checks help prevent downstream bias and redundancy.

# %%
# missing headlines
missing = news_df["headlines"].isna().sum()
total = len(news_df)

missing, total
# Out:
# (np.int64(280), 53650)

# %% [markdown]
# ## Remove missing headlines
#
# Rows with missing headline text are dropped since they cannot contribute
# to NLP analysis.

# %%
# drop missing
news_df = news_df.dropna(subset=["headlines"]).copy()
news_df.shape
# Out:
# (53370, 4)

# %% [markdown]
# ## Measure duplicate headline rate
#
# We calculate how many headlines are duplicated prior to cleaning.
# This provides context for how much redundancy exists in the raw data.

# %%
# duplicate rate before removal
dup_count = news_df["headlines"].duplicated().sum()
dup_count
# Out:
# np.int64(212)

# %% [markdown]
# ## Text cleaning function
#
# We define a conservative cleaning pipeline that:
# - lowercases text
# - removes URLs
# - normalizes whitespace
# - standardizes quotation marks
# - removes non-informative characters
#
# We intentionally keep numbers, percentages, and basic punctuation,
# which often carry meaning in financial headlines.

# %%
def clean_headline(text: str) -> str:
    text = str(text)

    # remove urls
    text = re.sub(r"http\S+|www\.\S+", " ", text)

    # normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()

    # lowercase
    text = text.lower()

    # remove weird quotes / normalize apostrophes
    text = text.replace("’", "'").replace("“", '"').replace("”", '"')

    # remove non-informative characters but keep %, $, ., -, /
    text = re.sub(r"[^a-z0-9\s\.\,\-\%\$\:\/\&\'\"]+", " ", text)

    # normalize whitespace again
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# ## Apply cleaning and inspect before/after examples
#
# We create two columns:
# - `headline_raw`: original headline text
# - `headline_clean`: cleaned version used for NLP
#
# Inspecting examples ensures that cleaning improves consistency
# without destroying semantic meaning.

# %%
news_df["headline_raw"] = news_df["headlines"].astype(str)
news_df["headline_clean"] = news_df["headline_raw"].apply(clean_headline)

news_df[["source", "headline_raw", "headline_clean"]].head(5)
# Out:
#   source  \
# 0   CNBC
# 1   CNBC
# 3   CNBC
# 4   CNBC
# 5   CNBC
#
#                                                                           headline_raw  \
# 0                 Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush
# 1                                       Cramer's lightning round: I would own Teradyne
# 3            Cramer's week ahead: Big week for earnings, even bigger week for vaccines
# 4                       IQ Capital CEO Keith Bliss says tech and healthcare will rally
# 5  Wall Street delivered the 'kind of pullback I've been waiting for,' Jim Cramer says
#
#                                                                         headline_clean
# 0                 jim cramer: a better way to invest in the covid-19 vaccine gold rush
# 1                                       cramer's lightning round: i would own teradyne
# 3            cramer's week ahead: big week for earnings, even bigger week for vaccines
# 4                       iq capital ceo keith bliss says tech and healthcare will rally
# 5  wall street delivered the 'kind of pullback i've been waiting for,' jim cramer says

# %% [markdown]
# The cleaned headlines preserve the original meaning while removing
# formatting noise that could negatively affect vectorization.

# %% [markdown]
# ## Remove empty or extremely short headlines
#
# Very short cleaned headlines are often artifacts or low-information rows.
# We remove these to improve downstream topic modeling and clustering quality.

# %%
news_df["clean_len"] = news_df["headline_clean"].str.len()
news_df["clean_len"].describe()
# Out:
# count    53370.000000
# mean        66.218981
# std         12.181449
# min         14.000000
# 25%         59.000000
# 50%         65.000000
# 75%         73.000000
# max        159.000000
# Name: clean_len, dtype: float64

# %%
# remove empties or extremely short strings (often junk)
news_df = news_df[news_df["clean_len"] >= 10].copy()
news_df.shape
# Out:
# (53370, 7)

# %% [markdown]
# ## Deduplicate cleaned headlines
#
# Exact duplicates are removed based on the cleaned headline text.
# This prevents repeated headlines from dominating similarity and topic analyses.

# %%
before = len(news_df)
news_df = news_df.drop_duplicates(subset=["headline_clean"]).copy()
after = len(news_df)

before, after, before - after
# Out:
# (53370, 53155, 215)

# %% [markdown]
# ## Normalize time field (best-effort)
#
# We attempt to parse the `time` column into a unified datetime format.
# Due to inconsistent timestamp formats across sources, parsing is done
# on a best-effort basis while retaining the raw time string.
#
# Parsed timestamps will be used for time-based analysis where available.

# %%
if "time" in news_df.columns:
    # best-effort parsing
    news_df["time_raw"] = news_df["time"].astype(str)
    news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
    news_df[["source", "time_raw", "time_parsed"]].head(5)
else:
    news_df["time_raw"] = None
    news_df["time_parsed"] = pd.NaT
# Out:
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:51  PM ET Fri, 17 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:33  PM ET Fri, 17 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:25  PM ET Fri, 17 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 4:24  PM ET Fri, 17 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:36  PM ET Thu, 16 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:23  PM ET Thu, 16 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 8:03  PM ET Thu, 16 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 8:54  AM ET Thu, 16 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 8:25  PM ET Wed, 15 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:51  PM ET Wed, 15 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:24  PM ET Wed, 15 July 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 6
May 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:07  PM ET Wed, 27 May 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 8:56  PM ET Tue, 26 May 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 8:31  PM ET Tue, 26 May 2020" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# ...
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:01  PM ET Tue,  9 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string "11:59  AM ET Wed, 10 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:24  PM ET Tue,  9 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:02  PM ET Mon,  8 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:41  PM ET Mon,  8 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:42  PM ET Mon,  8 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 3:37  PM ET Mon,  8 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:26  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:24  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:18  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 6:54  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:03  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:45  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:13  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 2:12  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string "12:00  PM ET Fri,  5 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:21  PM ET Thu,  4 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:30  PM ET Thu,  4 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:36  PM ET Thu,  4 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:27  PM ET Thu,  4 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:58  PM ET Thu,  4 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:21  PM ET Wed,  3 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:19  PM ET Wed,  3 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:32  PM ET Wed,  3 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:31  PM ET Wed,  3 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 2:02  PM ET Wed,  3 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:35  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:02  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:22  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:07  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:21  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:20  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 1:19  PM ET Tue,  2 Jan 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string "10:13  AM ET Wed, 27 Dec 2017" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string "10:15  AM ET Tue, 26 Dec 2017" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string "11:12  AM ET Thu, 20 Sept 2018" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 7:07  PM ET Fri, 22 Dec 2017" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)
# /tmp/ipykernel_20040/1135164311.py:4: FutureWarning: Parsed string " 6:52  PM ET Fri, 22 Dec 2017" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   news_df["time_parsed"] = pd.to_datetime(news_df["time_raw"], errors="coerce", utc=True)

# %% [markdown]
# ## Final cleaned dataset snapshot
#
# At this stage, the dataset includes:
# - a consistent `headline_clean` column for NLP
# - removed missing and duplicate rows
# - best-effort parsed timestamps
# - source labels preserved for comparison
#
# This cleaned dataset serves as the single source of truth
# for all subsequent feature engineering and modeling.

# %% [markdown]
# ## Save processed dataset
#
# We persist the cleaned dataset to `data/processed/` so downstream notebooks
# can load a stable, preprocessed input without repeating cleaning steps.

# %%
PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

out_path = PROCESSED_DIR / "news_clean.parquet"
news_df.to_parquet(out_path, index=False)

out_path.as_posix(), news_df.shape
# Out:
# ('../data/processed/news_clean.parquet', (53155, 9))

# %%
# fallback
out_csv = PROCESSED_DIR / "news_clean.csv"
news_df.to_csv(out_csv, index=False)
out_csv.as_posix()
# Out:
# '../data/processed/news_clean.csv'

# %% [markdown]
# ## Final sanity check
#
# We randomly sample cleaned headlines to visually confirm
# text quality and source labeling before moving on to modeling.

# %%
news_df[["source", "headline_clean"]].sample(10, random_state=42)
# Out:
#          source  \
# 40273  Guardian
# 14081   Reuters
# 23569   Reuters
# 50455  Guardian
# 25004   Reuters
# 44278  Guardian
# 11718   Reuters
# 31363   Reuters
# 11974   Reuters
# 40195  Guardian
#
#                                                                                       headline_clean
# 40273                                  call for tougher controls as buy now, pay later' deals spiral
# 14081                  wall street weekahead: small-cap shares poised to benefit from shift to value
# 23569                       trump says china trade talks going well, predicts 'good deal' or no deal
# 50455                                   brain cancer vaccine could extend lives of patients by years
# 25004                intel to get $1 billion state grant for $11 billion israel chip plant expansion
# 44278                                shell awaits court ruling on complicity in deaths of ogoni nine
# 11718                     brazil's ambev sets ambitious target to end plastic pollution in packaging
# 31363                             warren buffett donates $3.4 billion to gates' and family charities
# 11974  volkswagen's skoda auto 2019 deliveries dip to 1.24 million cars due to weaker sales in china
# 40195                      we can't rely on shops to revive our town centres. they need a new magnet
